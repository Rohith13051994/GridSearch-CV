# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'criterion': ['squared_error', 'absolute_error'],
    'max_features': ['auto', 'sqrt', 'log2'],
    'n_estimators': [10, 100]
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)

re=grid.cv_results_

#print(re)
grid_predictions = grid.predict(indep)

# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(dep,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.9679142066259576

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.251521      0.096759         0.003124        0.006248
# 1        1.390420      0.394562         0.031243        0.019760
# 2        0.060399      0.012143         0.009971        0.018483
# 3        0.806568      0.021994         0.028001        0.017984
# 4        0.083584      0.009283         0.003922        0.006050
# 5        0.954887      0.093359         0.035097        0.038305
# 6        0.509316      0.079625         0.012497        0.018218
# 7        6.941902      0.473815         0.027384        0.029750
# 8        0.374434      0.027396         0.019949        0.037936
# 9        4.015252      0.348287         0.065969        0.027635
# 10       0.311522      0.044026         0.006182        0.006270
# 11       3.438769      0.092095         0.021938        0.007599
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.836554
# 1   {'criterion': 'squared_error', 'max_features':...           0.844699
# 2   {'criterion': 'squared_error', 'max_features':...           0.843918
# 3   {'criterion': 'squared_error', 'max_features':...           0.855233
# 4   {'criterion': 'squared_error', 'max_features':...           0.835572
# 5   {'criterion': 'squared_error', 'max_features':...           0.858177
# 6   {'criterion': 'absolute_error', 'max_features'...           0.825344
# 7   {'criterion': 'absolute_error', 'max_features'...           0.839282
# 8   {'criterion': 'absolute_error', 'max_features'...           0.844527
# 9   {'criterion': 'absolute_error', 'max_features'...           0.858116
# 10  {'criterion': 'absolute_error', 'max_features'...           0.837264
# 11  {'criterion': 'absolute_error', 'max_features'...           0.857235
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.764501           0.829939           0.795551
# 1            0.770643           0.852068           0.817136
# 2            0.774694           0.842531           0.816777
# 3            0.777797           0.862877           0.832797
# 4            0.764453           0.848967           0.806589
# 5            0.779174           0.862141           0.825095
# 6            0.747624           0.836709           0.824537
# 7            0.768262           0.844491           0.822152
# 8            0.767034           0.844667           0.819925
# 9            0.781990           0.855227           0.827363
# 10           0.762609           0.853369           0.815853
# 11           0.781179           0.851544           0.825073
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.830379         0.811385        0.027522               11
# 1            0.836604         0.824230        0.029220                5
# 2            0.833793         0.822343        0.025712                7
# 3            0.838814         0.833504        0.029889                3
# 4            0.818297         0.814776        0.029029               10
# 5            0.844244         0.833766        0.030220                2
# 6            0.820120         0.810867        0.032092               12
# 7            0.836748         0.822187        0.027963                8
# 8            0.842347         0.823700        0.029821                6
# 9            0.847888         0.834117        0.028192                1
# 10           0.837756         0.821370        0.031712                9
# 11           0.846108         0.832228        0.027743                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 25
# BMI: 33
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])

#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[35504.93940305]
# C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
