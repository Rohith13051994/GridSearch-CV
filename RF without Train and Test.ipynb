# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
indep=sc.fit_transform(indep)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'criterion': ['squared_error', 'absolute_error'],
    'max_features': ['auto', 'sqrt', 'log2'],
    'n_estimators': [10, 100]
}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)

# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)

re=grid.cv_results_

#print(re)
grid_predictions = grid.predict(indep)

# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(dep,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}: 0.9697984465579111

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.062485      0.009879         0.003124    6.247520e-03
# 1        0.530947      0.031192         0.018745    6.248570e-03
# 2        0.044092      0.007047         0.003142    5.342978e-03
# 3        0.397428      0.025448         0.011978    6.198343e-03
# 4        0.045380      0.010977         0.006910    5.534861e-03
# 5        0.440232      0.023662         0.015621    6.289914e-07
# 6        0.350339      0.133078         0.003152    5.362974e-03
# 7        2.460638      0.208941         0.013036    3.301891e-03
# 8        0.165253      0.015570         0.003723    6.061069e-03
# 9        1.652879      0.204727         0.015879    9.915630e-03
# 10       0.145487      0.002700         0.003124    6.248188e-03
# 11       1.569750      0.152761         0.012895    6.485780e-03
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               sqrt                 10
# 9   absolute_error               sqrt                100
# 10  absolute_error               log2                 10
# 11  absolute_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.834943
# 1   {'criterion': 'squared_error', 'max_features':...           0.845892
# 2   {'criterion': 'squared_error', 'max_features':...           0.835306
# 3   {'criterion': 'squared_error', 'max_features':...           0.860490
# 4   {'criterion': 'squared_error', 'max_features':...           0.847198
# 5   {'criterion': 'squared_error', 'max_features':...           0.858208
# 6   {'criterion': 'absolute_error', 'max_features'...           0.840916
# 7   {'criterion': 'absolute_error', 'max_features'...           0.838156
# 8   {'criterion': 'absolute_error', 'max_features'...           0.839245
# 9   {'criterion': 'absolute_error', 'max_features'...           0.862441
# 10  {'criterion': 'absolute_error', 'max_features'...           0.850553
# 11  {'criterion': 'absolute_error', 'max_features'...           0.861852
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.760391           0.844149           0.815199
# 1            0.769956           0.854267           0.821574
# 2            0.772948           0.855981           0.806709
# 3            0.780903           0.868143           0.827898
# 4            0.762907           0.841319           0.801753
# 5            0.781295           0.861140           0.829695
# 6            0.742790           0.810880           0.805819
# 7            0.769527           0.857326           0.818301
# 8            0.752505           0.829115           0.806994
# 9            0.780891           0.857098           0.829009
# 10           0.778311           0.828672           0.812793
# 11           0.783660           0.861869           0.825397
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.821019         0.815140        0.029208               10
# 1            0.840279         0.826394        0.030194                5
# 2            0.829143         0.820018        0.028295                7
# 3            0.838963         0.835279        0.030791                2
# 4            0.824393         0.815514        0.030677                9
# 5            0.838795         0.833827        0.028781                4
# 6            0.827717         0.805624        0.033792               12
# 7            0.838912         0.824444        0.030107                6
# 8            0.827847         0.811141        0.031136               11
# 9            0.840886         0.834065        0.029104                3
# 10           0.825725         0.819211        0.023783                8
# 11           0.846527         0.835861        0.029326                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 23
# BMI: 33
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
preinput=sc.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
preinput
# Out:
# C:\Users\rohit\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.1539595 ,  0.38330685,  0.75107928, -1.0105187 ,  1.97058663]])

# %%
Future_Prediction=grid.predict(preinput)

#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[35468.7872785]
